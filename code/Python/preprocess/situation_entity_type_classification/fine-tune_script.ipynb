# %%
from transformers import BertTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
from torch.utils.data import Dataset, DataLoader
import torch
import os
import re
import numpy as np
import pickle as cPickle
import copy
import nltk
from bs4 import BeautifulSoup

# %%
# Initialize the BERT tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Load the pre-trained BERT model
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=8)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Load document lists
train_list = []
test_list = []
file_path = "" # include the file path for "train_test_split" -- it is in training_data/MASC_Wikipedia of the repo
with open(file_path, 'r') as f:
    for line in f.readlines():
        filename, genre, index, train_test = line.split()
        filename = filename[:-4]
        if train_test == 'train':
            train_list.append(filename)
        if train_test == 'test':
            test_list.append(filename)

# %%
# Load stored pos/ner parsing sentence
file_path1 = "" # include the file path for "masc_sentence_pos_ner_dict.pkl" -- it is in training_data
file_path2 = "" # include the file path for "explicit_connective.txt" -- it is in training_data
with open(file_path1, 'rb') as f:
    sentence_pos_ner_dict = cPickle.load(f)

connective_list = []
with open(file_path2, 'r') as f:
    for line in f.readlines():
        connective_list.append(line.strip())
connective_list = tuple(connective_list)

entity_type_list = ['STATE', 'EVENT', 'REPORT', 'GENERIC_SENTENCE', 'GENERALIZING_SENTENCE', 'QUESTION', 'IMPERATIVE', "CANNOT_DECIDE"]

def process_entity_type_label(entity_type):
    return entity_type_list.index(entity_type)

# %%
path1 =  "" # this should be the path to the annotations_xml folder inside MASC_Wikipedia
path2 = "" #this should be the path to the raw_text folder inside MASC_Wikipedia

class ClauseDataset(Dataset):
    def __init__(self, doc_list, tokenizer, max_length=128):
        self.clauses = []
        self.labels = []
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.process_docs(doc_list)
        print(f"Total clauses processed: {len(self.clauses)}")
        print(f"Total labels processed: {len(self.labels)}")

    def process_docs(self, doc_list):
        for doc_name in doc_list:
            doc_path = os.path.join(path1, doc_name + '.xml')
            raw_doc_path = os.path.join(path2, doc_name + '.txt')
            #print(f"Processing document: {doc_path}")
            doc_clause_list = self.process_doc(doc_path)
            #print(f"Number of clauses in document {doc_name}: {len(doc_clause_list)}")
            paras_clause_list = self.process_paragraph(doc_clause_list, raw_doc_path)
            #print(f"Number of paragraphs in document {doc_name}: {len(paras_clause_list)}")
            for para_clause_list in paras_clause_list:
                #print(f"Number of clauses in paragraph: {len(para_clause_list)}")
                for clause in para_clause_list:
                    clause_text, entity_type = clause[0], clause[1]
                    #print(f"Clause text: {clause_text}, Entity type: {entity_type}")
                    if entity_type in entity_type_list:
                        self.clauses.append(clause_text)
                        self.labels.append(process_entity_type_label(entity_type))
            print(f"Processed {len(self.clauses)} clauses so far.")

    def process_doc(self, doc_path):
        with open(doc_path, 'r') as doc:
            xml = BeautifulSoup(doc, "lxml-xml")  # Use lxml parser for XML
            clause_list = []
            for clause in xml.find_all('segment'):
                end = int(clause.attrs['end'])
                clause_text = clause.find('text').string
                label = 'CANNOT_DECIDE'
                annotation = clause.find('annotation', attrs={"annotator": "gold"})
                if annotation.has_attr('seType'):
                    label = annotation.attrs['seType']
                clause_list.append((clause_text, label, end))
            return clause_list

    def process_paragraph(self, doc_clause_list, raw_doc_path):
        with open(raw_doc_path, 'r') as raw_doc:
            raw_para_boundary_list = [m.start() + 1 for m in re.finditer('\n\n', raw_doc.read())]
            raw_para_boundary_list += [float('inf')]
            paras_clause_list = []

            index = 0
            for raw_para_boundary in raw_para_boundary_list:
                para_clause_list = []
                while index < len(doc_clause_list):
                    end_index = doc_clause_list[index][2]
                    if end_index <= raw_para_boundary:
                        para_clause_list.append(doc_clause_list[index])
                        index += 1
                    else:
                        break
                if len(para_clause_list) > 0:
                    paras_clause_list.append(para_clause_list)
            #print(f"Processed paragraphs: {len(paras_clause_list)}, Clauses in each paragraph: {[len(p) for p in paras_clause_list]}")
            return paras_clause_list

    def __len__(self):
        return len(self.clauses)

    def __getitem__(self, idx):
        clause = self.clauses[idx]
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            clause,
            add_special_tokens=True,
            max_length=self.max_length,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %%
train_dataset = ClauseDataset(train_list, tokenizer)
test_dataset = ClauseDataset(test_list, tokenizer)

train_dataloader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=16, shuffle=False)
# Out:
# Processed 85 clauses so far.
# Processed 179 clauses so far.
# Processed 283 clauses so far.
# Processed 986 clauses so far.
# Processed 1253 clauses so far.
# Processed 1541 clauses so far.
# Processed 1628 clauses so far.
# Processed 1711 clauses so far.
# Processed 1815 clauses so far.
# Processed 1922 clauses so far.
# Processed 2050 clauses so far.
# Processed 2175 clauses so far.
# Processed 2271 clauses so far.
# Processed 2692 clauses so far.
# Processed 2880 clauses so far.
# Processed 2917 clauses so far.
# Processed 2938 clauses so far.
# Processed 3119 clauses so far.
# Processed 3211 clauses so far.
# Processed 3235 clauses so far.
# Processed 3265 clauses so far.
# Processed 3309 clauses so far.
# Processed 3344 clauses so far.
# Processed 3372 clauses so far.
# Processed 3758 clauses so far.
# Processed 3803 clauses so far.
# Processed 3826 clauses so far.
# Processed 3839 clauses so far.
# Processed 3873 clauses so far.
# Processed 3919 clauses so far.
# Processed 3938 clauses so far.
# Processed 3963 clauses so far.
# Processed 4017 clauses so far.
# Processed 4034 clauses so far.
# Processed 4065 clauses so far.
# Processed 4109 clauses so far.
# Processed 4135 clauses so far.
# Processed 4149 clauses so far.
# Processed 4188 clauses so far.
# Processed 4253 clauses so far.
# Processed 4284 clauses so far.
# Processed 4308 clauses so far.
# Processed 4350 clauses so far.
# Processed 4369 clauses so far.
# Processed 4429 clauses so far.
# Processed 4472 clauses so far.
# Processed 4554 clauses so far.
# Processed 4583 clauses so far.
# Processed 4657 clauses so far.
# Processed 4730 clauses so far.
# Processed 4787 clauses so far.
# Processed 4874 clauses so far.
# Processed 4897 clauses so far.
# Processed 4946 clauses so far.
# Processed 4982 clauses so far.
# Processed 5010 clauses so far.
# Processed 5052 clauses so far.
# Processed 5071 clauses so far.
# Processed 5087 clauses so far.
# Processed 5141 clauses so far.
# Processed 5220 clauses so far.
# Processed 5249 clauses so far.
# Processed 5290 clauses so far.
# Processed 5311 clauses so far.
# Processed 5341 clauses so far.
# Processed 5451 clauses so far.
# Processed 5466 clauses so far.
# Processed 5506 clauses so far.
# Processed 5526 clauses so far.
# Processed 5547 clauses so far.
# Processed 5643 clauses so far.
# Processed 5663 clauses so far.
# Processed 5681 clauses so far.
# Processed 5814 clauses so far.
# Processed 5858 clauses so far.
# Processed 5875 clauses so far.
# Processed 5904 clauses so far.
# Processed 5939 clauses so far.
# Processed 5990 clauses so far.
# Processed 6043 clauses so far.
# Processed 6077 clauses so far.
# Processed 6127 clauses so far.
# Processed 6661 clauses so far.
# Processed 7087 clauses so far.
# Processed 7354 clauses so far.
# Processed 7675 clauses so far.
# Processed 7984 clauses so far.
# Processed 9033 clauses so far.
# Processed 10074 clauses so far.
# Processed 11092 clauses so far.
# Processed 12354 clauses so far.
# Processed 13052 clauses so far.
# Processed 14681 clauses so far.
# Processed 15219 clauses so far.
# Processed 16122 clauses so far.
# Processed 16213 clauses so far.
# Processed 16635 clauses so far.
# Processed 17268 clauses so far.
# Processed 17896 clauses so far.
# Processed 18438 clauses so far.
# Processed 18644 clauses so far.
# Processed 18865 clauses so far.
# Processed 19008 clauses so far.
# Processed 19457 clauses so far.
# Processed 19885 clauses so far.
# Processed 20237 clauses so far.
# Processed 20500 clauses so far.
# Processed 20720 clauses so far.
# Processed 20888 clauses so far.
# Processed 21088 clauses so far.
# Processed 21169 clauses so far.
# Processed 21222 clauses so far.
# Processed 21309 clauses so far.
# Processed 22898 clauses so far.
# Processed 22968 clauses so far.
# Processed 23021 clauses so far.
# Processed 23083 clauses so far.
# Processed 23111 clauses so far.
# Processed 23160 clauses so far.
# Processed 23182 clauses so far.
# Processed 23227 clauses so far.
# Processed 23259 clauses so far.
# Processed 23297 clauses so far.
# Processed 23328 clauses so far.
# Processed 23365 clauses so far.
# Processed 23382 clauses so far.
# Processed 23410 clauses so far.
# Processed 23436 clauses so far.
# Processed 23465 clauses so far.
# Processed 23499 clauses so far.
# Processed 23538 clauses so far.
# Processed 23588 clauses so far.
# Processed 23620 clauses so far.
# Processed 23660 clauses so far.
# Processed 23690 clauses so far.
# Processed 23725 clauses so far.
# Processed 23754 clauses so far.
# Processed 23813 clauses so far.
# Processed 23834 clauses so far.
# Processed 23855 clauses so far.
# Processed 23888 clauses so far.
# Processed 23927 clauses so far.
# Processed 23996 clauses so far.
# Processed 24025 clauses so far.
# Processed 24058 clauses so far.
# Processed 24106 clauses so far.
# Processed 24130 clauses so far.
# Processed 24271 clauses so far.
# Processed 24346 clauses so far.
# Processed 24391 clauses so far.
# Processed 24494 clauses so far.
# Processed 24559 clauses so far.
# Processed 24664 clauses so far.
# Processed 24732 clauses so far.
# Processed 24819 clauses so far.
# Processed 24844 clauses so far.
# Processed 24874 clauses so far.
# Processed 24897 clauses so far.
# Processed 24903 clauses so far.
# Processed 25720 clauses so far.
# Processed 25736 clauses so far.
# Processed 25755 clauses so far.
# Processed 25859 clauses so far.
# Processed 26064 clauses so far.
# Processed 26151 clauses so far.
# Processed 26251 clauses so far.
# Processed 26292 clauses so far.
# Processed 26462 clauses so far.
# Processed 26587 clauses so far.
# Processed 26661 clauses so far.
# Processed 26892 clauses so far.
# Processed 26897 clauses so far.
# Processed 26917 clauses so far.
# Processed 26941 clauses so far.
# Processed 26947 clauses so far.
# Processed 26953 clauses so far.
# Processed 26967 clauses so far.
# Processed 26979 clauses so far.
# Processed 27065 clauses so far.
# Processed 27078 clauses so far.
# Processed 27092 clauses so far.
# Processed 27106 clauses so far.
# Processed 27116 clauses so far.
# Processed 27126 clauses so far.
# Processed 27142 clauses so far.
# Processed 27158 clauses so far.
# Processed 27178 clauses so far.
# Processed 27191 clauses so far.
# Processed 27204 clauses so far.
# Processed 27239 clauses so far.
# Processed 27256 clauses so far.
# Processed 27268 clauses so far.
# Processed 27281 clauses so far.
# Processed 27296 clauses so far.
# Processed 27310 clauses so far.
# Processed 27320 clauses so far.
# Processed 27649 clauses so far.
# Processed 27826 clauses so far.
# Processed 28138 clauses so far.
# Processed 28327 clauses so far.
# Processed 28497 clauses so far.
# Processed 28674 clauses so far.
# Processed 28934 clauses so far.
# Processed 29176 clauses so far.
# Processed 29423 clauses so far.
# Processed 29523 clauses so far.
# Processed 30397 clauses so far.
# Processed 30496 clauses so far.
# Processed 30583 clauses so far.
# Processed 30660 clauses so far.
# Processed 30721 clauses so far.
# Processed 30799 clauses so far.
# Processed 30905 clauses so far.
# Processed 30993 clauses so far.
# Processed 31098 clauses so far.
# Processed 31183 clauses so far.
# Processed 31273 clauses so far.
# Processed 31487 clauses so far.
# Processed 31517 clauses so far.
# Processed 31614 clauses so far.
# Processed 31784 clauses so far.
# Processed 31970 clauses so far.
# Processed 32160 clauses so far.
# Processed 32336 clauses so far.
# Processed 32450 clauses so far.
# Processed 32582 clauses so far.
# Processed 32675 clauses so far.
# Processed 32873 clauses so far.
# Processed 33082 clauses so far.
# Processed 33200 clauses so far.
# Processed 33291 clauses so far.
# Processed 33392 clauses so far.
# Processed 33499 clauses so far.
# Processed 33592 clauses so far.
# Processed 33719 clauses so far.
# Processed 33910 clauses so far.
# Processed 33977 clauses so far.
# Processed 34049 clauses so far.
# Processed 34137 clauses so far.
# Processed 34355 clauses so far.
# Processed 34451 clauses so far.
# Processed 34547 clauses so far.
# Processed 34669 clauses so far.
# Processed 34748 clauses so far.
# Processed 34777 clauses so far.
# Processed 34856 clauses so far.
# Processed 35088 clauses so far.
# Processed 35184 clauses so far.
# Processed 35268 clauses so far.
# Processed 35363 clauses so far.
# Processed 35448 clauses so far.
# Processed 35668 clauses so far.
# Processed 35769 clauses so far.
# Processed 35866 clauses so far.
# Processed 35974 clauses so far.
# Processed 36070 clauses so far.
# Processed 36152 clauses so far.
# Processed 36361 clauses so far.
# Processed 36457 clauses so far.
# Processed 36649 clauses so far.
# Processed 36742 clauses so far.
# Processed 36837 clauses so far.
# Processed 36982 clauses so far.
# Processed 37082 clauses so far.
# Processed 37168 clauses so far.
# Processed 37263 clauses so far.
# Processed 37396 clauses so far.
# Processed 37502 clauses so far.
# Processed 37541 clauses so far.
# Processed 37653 clauses so far.
# Processed 37873 clauses so far.
# Processed 38053 clauses so far.
# Processed 38141 clauses so far.
# Processed 38338 clauses so far.
# Processed 38532 clauses so far.
# Processed 38565 clauses so far.
# Processed 38749 clauses so far.
# Processed 38853 clauses so far.
# Processed 39075 clauses so far.
# Processed 39153 clauses so far.
# Processed 39250 clauses so far.
# Processed 39494 clauses so far.
# Processed 39601 clauses so far.
# Processed 39633 clauses so far.
# Processed 39827 clauses so far.
# Total clauses processed: 39827
# Total labels processed: 39827
# Processed 164 clauses so far.
# Processed 257 clauses so far.
# Processed 418 clauses so far.
# Processed 526 clauses so far.
# Processed 582 clauses so far.
# Processed 676 clauses so far.
# Processed 887 clauses so far.
# Processed 907 clauses so far.
# Processed 927 clauses so far.
# Processed 1030 clauses so far.
# Processed 1051 clauses so far.
# Processed 1097 clauses so far.
# Processed 1114 clauses so far.
# Processed 1153 clauses so far.
# Processed 1206 clauses so far.
# Processed 1255 clauses so far.
# Processed 1279 clauses so far.
# Processed 1323 clauses so far.
# Processed 1378 clauses so far.
# Processed 1540 clauses so far.
# Processed 1852 clauses so far.
# Processed 2926 clauses so far.
# Processed 3866 clauses so far.
# Processed 4238 clauses so far.
# Processed 4413 clauses so far.
# Processed 4587 clauses so far.
# Processed 4794 clauses so far.
# Processed 4952 clauses so far.
# Processed 5219 clauses so far.
# Processed 5380 clauses so far.
# Processed 5450 clauses so far.
# Processed 5519 clauses so far.
# Processed 5597 clauses so far.
# Processed 5689 clauses so far.
# Processed 5788 clauses so far.
# Processed 5868 clauses so far.
# Processed 5939 clauses so far.
# Processed 5971 clauses so far.
# Processed 6040 clauses so far.
# Processed 6080 clauses so far.
# Processed 6126 clauses so far.
# Processed 6192 clauses so far.
# Processed 6257 clauses so far.
# Processed 6269 clauses so far.
# Processed 6286 clauses so far.
# Processed 6299 clauses so far.
# Processed 6318 clauses so far.
# Processed 6329 clauses so far.
# Processed 6343 clauses so far.
# Processed 6376 clauses so far.
# Processed 6397 clauses so far.
# Processed 6421 clauses so far.
# Processed 6485 clauses so far.
# Processed 6564 clauses so far.
# Processed 6601 clauses so far.
# Processed 6860 clauses so far.
# Processed 6937 clauses so far.
# Processed 7285 clauses so far.
# Processed 7395 clauses so far.
# Processed 7488 clauses so far.
# Processed 7537 clauses so far.
# Processed 7619 clauses so far.
# Processed 7704 clauses so far.
# Processed 7731 clauses so far.
# Processed 7833 clauses so far.
# Processed 7946 clauses so far.
# Processed 8046 clauses so far.
# Processed 8073 clauses so far.
# Processed 8162 clauses so far.
# Processed 8394 clauses so far.
# Processed 8494 clauses so far.
# Processed 8691 clauses so far.
# Processed 8806 clauses so far.
# Processed 8900 clauses so far.
# Processed 8983 clauses so far.
# Processed 9128 clauses so far.
# Processed 9260 clauses so far.
# Processed 9358 clauses so far.
# Processed 9464 clauses so far.
# Processed 9531 clauses so far.
# Processed 9582 clauses so far.
# Processed 9702 clauses so far.
# Total clauses processed: 9702
# Total labels processed: 9702

# %%
import numpy as np

def calculate_label_distribution(dataset, entity_type_list):
    label_counts = np.zeros(len(entity_type_list), dtype=int)
    for item in dataset:
        label = item['labels'].item()  # Extract the label
        label_counts[label] += 1
    return label_counts

# Calculate label distribution for training dataset
train_label_counts = calculate_label_distribution(train_dataset, entity_type_list)
test_label_counts = calculate_label_distribution(test_dataset, entity_type_list)

# Print label distribution
print("Training Set Label Distribution:")
for i, count in enumerate(train_label_counts):
    print(f"{entity_type_list[i]}: {count}")

print("\nTest Set Label Distribution:")
for i, count in enumerate(test_label_counts):
    print(f"{entity_type_list[i]}: {count}")
# Out:
# Training Set Label Distribution:
# STATE: 18337
# EVENT: 9688
# REPORT: 1617
# GENERIC_SENTENCE: 7582
# GENERALIZING_SENTENCE: 1466
# QUESTION: 1056
# IMPERATIVE: 1046
# CANNOT_DECIDE: 8737
#
# Test Set Label Distribution:
# STATE: 3544
# EVENT: 1733
# REPORT: 323
# GENERIC_SENTENCE: 1578
# GENERALIZING_SENTENCE: 316
# QUESTION: 207
# IMPERATIVE: 236
# CANNOT_DECIDE: 1765

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("CUDA version:", torch.version.cuda)
    print("Number of GPUs:", torch.cuda.device_count())
    print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# PyTorch version: 2.3.1+cu121
# CUDA available: True
# CUDA version: 12.1
# Number of GPUs: 1
# GPU Name: Tesla T4

# %% [markdown]
# training

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=3,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    eval_strategy='epoch'  # Updated parameter name
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics
)

# Train the model
trainer.train()

model_save_path = "/content/drive/MyDrive/Stanford Summer 23-34/children book project/trained_model_new"
trainer.save_model(model_save_path)
tokenizer.save_pretrained(model_save_path)
# Save the training arguments

import json
training_args_dict = training_args.to_dict()
with open(os.path.join(model_save_path, 'training_args.json'), 'w') as f:
    json.dump(training_args_dict, f)
# Out:
#     <div>
#
#       <progress value='14937' max='14937' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [14937/14937 59:21, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.273400</td>
#       <td>0.642180</td>
#       <td>0.800454</td>
#       <td>0.797439</td>
#       <td>0.800454</td>
#       <td>0.796676</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.339400</td>
#       <td>0.711653</td>
#       <td>0.815296</td>
#       <td>0.812880</td>
#       <td>0.815296</td>
#       <td>0.811989</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.267500</td>
#       <td>0.976719</td>
#       <td>0.817666</td>
#       <td>0.816907</td>
#       <td>0.817666</td>
#       <td>0.816593</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
results = trainer.evaluate()
print(results)
# Out:
#     <div>
#
#       <progress value='1213' max='1213' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1213/1213 01:08]
#     </div>
# {'eval_loss': 0.9767186045646667, 'eval_accuracy': 0.8176664605236034, 'eval_precision': 0.8169065481118306, 'eval_recall': 0.8176664605236034, 'eval_f1': 0.8165929589822221, 'eval_runtime': 69.0489, 'eval_samples_per_second': 140.509, 'eval_steps_per_second': 17.567, 'epoch': 3.0}

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    accuracy = accuracy_score(labels, preds)
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')
    return {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1': f1
    }

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    compute_metrics=compute_metrics  # Pass the compute_metrics function here
)

# %%
# Evaluate the model
results = trainer.evaluate(eval_dataset=test_dataset)
print(results)
# Out:
#     <div>
#
#       <progress value='607' max='607' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [607/607 01:05]
#     </div>
# {'eval_loss': 0.07353400439023972, 'eval_accuracy': 0.9787672644815502, 'eval_precision': 0.9787760006984491, 'eval_recall': 0.9787672644815502, 'eval_f1': 0.9787390533902349, 'eval_runtime': 65.6505, 'eval_samples_per_second': 147.783, 'eval_steps_per_second': 9.246}

# %%
from collections import Counter

train_labels = [label for label in train_dataset.labels]
test_labels = [label for label in test_dataset.labels]

train_label_distribution = Counter(train_labels)
test_label_distribution = Counter(test_labels)

print(f"Training label distribution: {train_label_distribution}")
print(f"Test label distribution: {test_label_distribution}")
# Out:
# Training label distribution: Counter({0: 18337, 1: 9688, 7: 8737, 3: 7582, 2: 1617, 4: 1466, 5: 1056, 6: 1046})
# Test label distribution: Counter({0: 3544, 7: 1765, 1: 1733, 3: 1578, 2: 323, 4: 316, 6: 236, 5: 207})

# %%
from sklearn.model_selection import StratifiedKFold

def cross_validate_model(model, dataset, n_splits=5):
    skf = StratifiedKFold(n_splits=n_splits)
    metrics_list = []

    for train_index, val_index in skf.split(dataset.clauses, dataset.labels):
        train_subset = torch.utils.data.Subset(dataset, train_index)
        val_subset = torch.utils.data.Subset(dataset, val_index)

        train_dataloader = DataLoader(train_subset, batch_size=8, shuffle=True)
        val_dataloader = DataLoader(val_subset, batch_size=8, shuffle=False)

        trainer = Trainer(
            model=model,
            args=training_args,
            train_dataset=train_subset,
            eval_dataset=val_subset,
            compute_metrics=compute_metrics
        )

        trainer.train()
        metrics = trainer.evaluate(eval_dataset=val_subset)
        metrics_list.append(metrics)

    avg_metrics = {
        'eval_loss': np.mean([m['eval_loss'] for m in metrics_list]),
        'eval_accuracy': np.mean([m['eval_accuracy'] for m in metrics_list]),
        'eval_precision': np.mean([m['eval_precision'] for m in metrics_list]),
        'eval_recall': np.mean([m['eval_recall'] for m in metrics_list]),
        'eval_f1': np.mean([m['eval_f1'] for m in metrics_list])
    }

    return avg_metrics

# Perform cross-validation
cross_val_metrics = cross_validate_model(model, train_dataset)
print(f"Cross-validation metrics: {cross_val_metrics}")
